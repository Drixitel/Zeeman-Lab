# %%
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.colors as colors

from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

import scipy.stats as stat
from scipy.optimize import curve_fit
from scipy.signal import find_peaks, peak_prominences, peak_widths
from scipy.stats import linregress

import itertools

import helperfile as hf

# %% [markdown]
# # Also not Great

# %%
# Block of Code to show FIT Image

# bins, intensities  = hf.CreateData('180NoBRun1.txt')
# bins, intensities =  np.array(bins), np.array(intensities)
# hf.Plots(bins, intensities, "B=0.384 kG, Polarize = 180 deg, Intensity Plot - Full set", 'Bins', 'Intensity [ADU] ', figsize0= 15, figsize1=4)

# %%
# STEP 1: Load Data 
xy = np.loadtxt('XYR2_180_Dic.txt', dtype=int, delimiter=',')
print(type(xy))
print(f"Number of trials to examine = {len(xy)/2}\nTotal Number of arrays = {len(xy)}")
# Out:
# <class 'numpy.ndarray'>
# Number of trials to examine = 10.0
# Total Number of arrays = 20

# %%
# # STEP 2: Check all graphs  

# hf.MakeManyPlots(xy)

# %%
# STEP 5: TRUNCATE TO THE FIRST ORDER
peaks1, x_1, y_1 = hf.LabelPeaks_ShrinkData(xy[0],xy[1],250,500,1700)
peaks2, x_2, y_2 = hf.LabelPeaks_ShrinkData(xy[2],xy[3],250,500,1700)
peaks3, x_3, y_3 = hf.LabelPeaks_ShrinkData(xy[4],xy[5],250,500,1700)
peaks4, x_4, y_4 = hf.LabelPeaks_ShrinkData(xy[6],xy[7],250,500,1700)
peaks5, x_5, y_5 = hf.LabelPeaks_ShrinkData(xy[8],xy[9],250,500,1700)
peaks6, x_6, y_6 = hf.LabelPeaks_ShrinkData(xy[10],xy[11],250,500,1700)
peaks7, x_7, y_7 = hf.LabelPeaks_ShrinkData(xy[12],xy[13],250,500,1700)
peaks8, x_8, y_8 = hf.LabelPeaks_ShrinkData(xy[14],xy[15],250,500,1700)
peaks9, x_9, y_9 = hf.LabelPeaks_ShrinkData(xy[16],xy[17],250,500,1700)
peaks10, x_10, y_10 = hf.LabelPeaks_ShrinkData(xy[18],xy[19],250,500,1700)
# peaks11, x_11, y_11 = hf.LabelPeaks_ShrinkData(xy[20],xy[21],180,560,1700)
# peaks12, x_12, y_12 = hf.LabelPeaks_ShrinkData(xy[22],xy[23],180,580,1700)


# hf.Plots(x_1,y_1, 
#     'B = 1.100kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=8
#     )
# hf.PlotNewPeaks(peaks1,xy[1])

# hf.Plots(x_2,y_2, 
#     'B = 0.200kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks2,xy[3])

# hf.Plots(x_3,y_3, 
#     'B = 0.300kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks3,xy[5])


# hf.Plots(x_4,y_4, 
#     'B = 0.400kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks4,xy[7])


# hf.Plots(x_5,y_5, 
#     'B = 0.500kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks5,xy[9])

# hf.Plots(x_6,y_6, 
#     'B = 0.600kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks6,xy[11])

# hf.Plots(x_7,y_7, 
#     'B = 0.700kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks7,xy[13])

# hf.Plots(x_8,y_8, 
#     'B = 0.800kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks8,xy[15])

# hf.Plots(x_9,y_9, 
#     'B = 0.900kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks9,xy[17])

hf.Plots(x_10,y_10, 
    'B = 1.000kG, Intensity Plot [510x765][9um squares]', 
    'Bins (pixels)', 'Intensity (ADU)', 
    # figsize0=12, figsize1=6
    )
hf.PlotNewPeaks(peaks10,xy[19])

# hf.Plots(x_11,y_11, 
#     'B = 0.384kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks11,xy[21])

# hf.Plots(x_12,y_12, 
#     'B = 0.394kG, Intensity Plot [510x765][9um squares]', 
#     'Bins (pixels)', 'Intensity (ADU)', 
#     # figsize0=12, figsize1=6
#     )
# hf.PlotNewPeaks(peaks12,xy[23])
# Out:
# Data ratio set

# %%
# STEP 6: CREATE RADIUS ARRAY 
B1 = 1.100E3 #Gauss
R1_1 = hf.RadiusMeter(peaks1[0], peaks1[-1])
R1_2 = hf.RadiusMeter(peaks1[2], peaks1[-2])
# R1_3 = hf.RadiusMeter(peaks1[2], peaks1[-4])

B2 = 0.200E3
R2_1 = hf.RadiusMeter(peaks2[0], peaks2[-1])
R2_2 = hf.RadiusMeter(peaks2[2], peaks2[-2])
# R2_3 = hf.RadiusMeter(peaks2[2], peaks2[-3])

B3 = 0.300E3
R3_1 = hf.RadiusMeter(peaks3[0], peaks3[-1])
R3_2 = hf.RadiusMeter(peaks3[2], peaks3[-2])
# R3_3 = hf.RadiusMeter(peaks3[3], peaks3[-4])

B4 = 0.400E3
R4_1 = hf.RadiusMeter(peaks4[0], peaks4[-1])
R4_2 = hf.RadiusMeter(peaks4[2], peaks4[-2])
# R4_3 = hf.RadiusMeter(peaks4[3], peaks4[-4])

B5 = 0.500E3
R5_1 = hf.RadiusMeter(peaks5[0], peaks5[-1])
R5_2 = hf.RadiusMeter(peaks5[1], peaks5[-2])
# R5_3 = hf.RadiusMeter(peaks5[3], peaks5[-4])

B6 = 0.600E3
R6_1 = hf.RadiusMeter(peaks6[0], peaks6[-1])
R6_2 = hf.RadiusMeter(peaks6[1], peaks6[-2])
# R6_3 = hf.RadiusMeter(peaks6[3], peaks6[-4])

B7 = 0.700E3
R7_1 = hf.RadiusMeter(peaks7[0], peaks7[-1])
R7_2 = hf.RadiusMeter(peaks7[1], peaks7[-2])
# R7_3 = hf.RadiusMeter(peaks7[3], peaks7[-4])

B8 = 0.800E3
R8_1 = hf.RadiusMeter(peaks8[0], peaks8[-1])
R8_2 = hf.RadiusMeter(peaks8[1], peaks8[-2])
# R8_3 = hf.RadiusMeter(peaks8[3], peaks8[-4])

B9 = 0.900E3
R9_1 = hf.RadiusMeter(peaks9[0], peaks9[-1])
R9_2 = hf.RadiusMeter(peaks9[2], peaks9[-2])
# R9_3 = hf.RadiusMeter(peaks9[3], peaks9[-4])

B10 = 1.000E3
R10_1 = hf.RadiusMeter(peaks10[0], peaks10[-1])
R10_2 = hf.RadiusMeter(peaks10[2], peaks10[-2])
# R10_3 = hf.RadiusMeter(peaks10[3], peaks10[-4])

# B11 = 0.384E3
# R11_1 = hf.RadiusMeter(peaks11[0], peaks11[-1])
# R11_2 = hf.RadiusMeter(peaks11[2], peaks11[-2])
# # R11_3 = hf.RadiusMeter(peaks11[2], peaks11[-4])

# B12 = 0.394E3
# R12_1 = hf.RadiusMeter(peaks12[0], peaks12[-1])
# R12_2 = hf.RadiusMeter(peaks12[2], peaks12[-3])
# # R11_3 = hf.RadiusMeter(peaks11[2], peaks11[-4])

radii = [
    R1_1, R1_2, 
    R2_1, R2_2, 
    R3_1, R3_2, 
    R4_1, R4_2, 
    R5_1, R5_2, 
    R6_1, R6_2, 
    R7_1, R7_2, 
    R8_1, R8_2, 
    R9_1, R9_2, 
    R10_1, R10_2, 
    # R11_1, R11_2, 
    # R12_1, R12_2, 
]

# EACH SET OF GRAPHS WILL CONTRIBUTE 1 DELTA E
B = [
    B1,
    B2,
    B3,
    B4,
    B5,
    B6,
    B7,
    B8,
    B9,
    B10,
    # B11,
    # B12,
]

B = np.array(B)

# %%
# STEP 7: CREATE THETA ARRAYS 
thetas = hf.ThetasRadArray(radii)
#saved as txt to use in Error prop File to return Yerr 
np.savetxt("Run2Thetas180.txt", thetas, delimiter =", ")

# %%
# STEP 8: CREATE DELTA E ARRAYS 
delE_180 = hf.DeltaEPrime180(thetas)
print(len(delE_180))
# Out:
# 10

# %%
# STEP 9: PLOT 

# plt.scatter(B,delE_180)

# %%
# STEP 10: CREATE FIT FUNCTION 
# E = A*MU_0*B - TWO UNKNOWNS
# E = 0.5*MU_0B - A KNOWN 
# E = A*MU*B - MU_0 KNOWN 

# TWO UNKNOWNS 
def DelE1(B,mu_0,a):
    mu = 9.2741E-21 # erg/G
    A = 2.5
    return a*mu_0*B

p01 = [9.3E-21, 2.3]

# A KNOWN
def DelE2(B,mu_0):
    mu = 9.2741E-21 # erg/G
    A = 2.5
    return A*mu_0*B

p02 = [9.3E-21]

# MU KNOWN
def DelE3(B,a):
    mu = 9.2741E-21 # erg/G
    A = 2.5
    return a*mu*B

p03 = [2.3]

# %%
# STEP 11: LOAD ERROR FROM Error90.ipynb 
# AND ASSIGN B ERROR 

sigmaE = np.loadtxt('Run2Eerr180.txt', delimiter=',')




# CREATE SAME SIZE ARRAY
Barr = np.ones(len(B))
# ERROR
sigmaB = 0.05E3 # Gauss 
Berr = sigmaB*Barr

# %%
# STEP 12: APPLY FIT

# TWO UNKNOWNS 
popt1, pcov1 = curve_fit( 
                    DelE1,
                    B,
                    delE_180,
                    p0= p01, 
                    absolute_sigma=True,
                    sigma=sigmaE
                    )

for i in range(0,len(popt1)):
    print('param ',i,' = ',popt1[i], '+/-', np.sqrt(pcov1[i,i]))

# A KNOWN
print('\nA = 0.5 Known, fit mu_0 : 9.2741E-21')
popt2, pcov2 = curve_fit( 
                    DelE2,
                    B,
                    delE_180,
                    p0= p02, 
                    absolute_sigma=True,
                    sigma=sigmaE
                    )

for i in range(0,len(popt2)):
    print('param ',i,' = ',popt2[i], '+/-', np.sqrt(pcov2[i,i]))

# MU KNOWN
print('\nmu_0 = 9.2741E-21, fit A : Assuming A = 1/2')
popt3, pcov3 = curve_fit( 
                    DelE3,
                    B,
                    delE_180,
                    p0= p03, 
                    absolute_sigma=True,
                    sigma=sigmaE
                    )

for i in range(0,len(popt3)):
    print('param ',i,' = ',popt3[i], '+/-', np.sqrt(pcov3[i,i]))
# Out:
# param  0  =  1.8974800042827553e-20 +/- nan
# param  1  =  3.82735250404117 +/- nan
#
# A = 0.5 Known, fit mu_0 : 9.2741E-21
# param  0  =  2.904934086783198e-20 +/- 2.541366115136471e-22
#
# mu_0 = 9.2741E-21, fit A : Assuming A = 1/2
# param  0  =  7.830770897867861 +/- 0.0685070815013635
# C:\Users\mpmun\AppData\Local\Temp\ipykernel_27304\2355550925.py:14: RuntimeWarning: invalid value encountered in sqrt
#   print('param ',i,' = ',popt1[i], '+/-', np.sqrt(pcov1[i,i]))

# %%
# PLOT1

#style
hfont = {'fontname':'Consolas'}
plt.figure()
plt.style.use('bmh')


# Better looking line
B_line = np.linspace(min(B), max(B), 1000)
fit1 = DelE1(B, *popt1)

#data
plt.plot(B, fit1, label = 'Fit: mu_0= %1.3e erg/G A= %1.3f' % tuple(popt1), color = 'red')

plt.errorbar(
    B, 
    delE_180, 
    yerr= sigmaE,
    xerr= Berr, 
    fmt='o', 
    label = 'Data', 
    color='black',
    alpha =0.5
    )

#labels
plt.title("Delta E vs. Magnetic Field B [Sigma]", **hfont)
plt.xlabel('Magnetic Field B (Gaus)', **hfont)
plt.ylabel('Energy Shift (erg)', **hfont)
plt.legend(loc=2)

print(popt1)

# hf.SaveFigure("PiDelEvsB90Run3_1.png")
# Out:
# [1.8974800e-20 3.8273525e+00]

# %%
# PLOT2

#style
hfont = {'fontname':'Consolas'}
plt.figure()
plt.style.use('bmh')


# Better looking line
B_line = np.linspace(min(B), max(B), 1000)
fit2 = DelE2(B, *popt2)

#data
plt.plot(B, fit2, label = 'Fit: mu_0= %1.3e erg/G' % tuple(popt2), color = 'm')

plt.errorbar(
    B, 
    delE_180, 
    yerr= sigmaE,
    xerr= Berr, 
    fmt='o', 
    label = 'Data', 
    color='black',
    alpha =0.5
    )

#labels
plt.title("Delta E vs. Magnetic Field B [Sigma]", **hfont)
plt.xlabel('Magnetic Field B (Gaus)', **hfont)
plt.ylabel('Energy Shift (erg)', **hfont)
plt.legend(loc=2)

print(popt2)

# hf.SaveFigure("PiDelEvsB90Run3_2.png")
# Out:
# [2.90493409e-20]

# %%
# PLOT3

#style
hfont = {'fontname':'Consolas'}
plt.figure()
plt.style.use('bmh')


# Better looking line
B_line = np.linspace(min(B), max(B), 1000)
fit3 = DelE3(B, *popt3)

#data
plt.plot(B, fit3, label = 'Fit: A= %1.3f' % tuple(popt3), color = 'b')

plt.errorbar(
    B, 
    delE_180, 
    yerr= sigmaE,
    xerr= Berr, 
    fmt='o', 
    label = 'Data', 
    color='black',
    alpha =0.5
    )

#labels
plt.title("Delta E vs. Magnetic Field B [Sigma]", **hfont)
plt.xlabel('Magnetic Field B (Gaus)', **hfont)
plt.ylabel('Energy Shift (erg)', **hfont)
plt.legend(loc=2)

print(popt3)

# hf.SaveFigure("PiDelEvsB90Run3_3.png")
# Out:
# [7.8307709]

# %%
# this is with the constraint of A = 1/2
print('Fit: mu_0 and A')
hf.Chi2Values(DelE1,B,delE_180,popt1,sigmaE)

print('\n\n')
print('Fit: mu_0, A = 0.5')
hf.Chi2Values(DelE2,B,delE_180,popt2,sigmaE)

print('\n\n')
print('Fit: A, mu_0 = 9.2741E-21')
hf.Chi2Values(DelE3,B,delE_180,popt3,sigmaE)
# Out:
# Fit: mu_0 and A
# Chi-square:  7757.485819570083
# Degrees of freedom:  8
# Reduced chi-square:  969.6857274462603
# CDF:  1.0
# p-test value:  0.0
#
#
#
# Fit: mu_0, A = 0.5
# Chi-square:  7757.485819543088
# Degrees of freedom:  9
# Reduced chi-square:  861.9428688381208
# CDF:  1.0
# p-test value:  0.0
#
#
#
# Fit: A, mu_0 = 9.2741E-21
# Chi-square:  7757.485819543087
# Degrees of freedom:  9
# Reduced chi-square:  861.9428688381208
# CDF:  1.0
# p-test value:  0.0

# %%
# Try  a larger set of values---- This does not work becuse the values are so spead out
