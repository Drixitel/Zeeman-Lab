# %%
#packages needed 
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.colors as colors

from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

from scipy.optimize import curve_fit
import scipy.stats as stat
from scipy.signal import find_peaks
from scipy.signal import peak_widths

import helperfile as hp

# %% [markdown]
# # Plot and save ring images

# %%
B0, B0_data, B0_infor =hp. GetImage("AllDataFiles/B0D180.FIT")
# Out:
# Filename: c:\Users\mpmun\OneDrive\Documents\1Pichardo\UCSC\Spring2022\Phys134\134code\Code\Zeeman\Data\AllDataFiles\B0D180.FIT
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      38   (765, 510)   int16 (rescales to uint16)

# %%
hp.PlotRings(B0_data, 
        "B=0.001kG, Ring Plot, deg:180 [510x765][9umx9um]", 
        'Bins 510 Pixels',
        'Bins 765 Pixels',
        figsize0=10, 
        figsize1=8
        )

plt.savefig("Graphs/B0RingPlot.png", bbox_inches ='tight' )
# Out:
# Ratio override to (10,8)

# %%
B0, B0_data, B0_infor =hp.GetImage("AllDataFiles/0B_control.FIT")
hp.PlotRings(B0_data, 
        "B=0.001kG, Ring Plot, deg:90 [510x765][9umx9um]", 
        'Bins 510 Pixels',
        'Bins 765 Pixels',
        figsize0=10, 
        figsize1=8
        )

plt.savefig("Graphs/B0RingPlot.png", bbox_inches ='tight' )
# Out:
# Filename: c:\Users\mpmun\OneDrive\Documents\1Pichardo\UCSC\Spring2022\Phys134\134code\Code\Zeeman\Data\AllDataFiles\0B_control.FIT
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      40   (765, 510)   int16 (rescales to uint16)
# Ratio override to (10,8)
